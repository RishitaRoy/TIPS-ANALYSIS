# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("https://raw.githubusercontent.com/mwaskom/seaborn-data/master/tips.csv")
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    object
#  3   smoker      244 non-null    object
#  4   day         244 non-null    object
#  5   time        244 non-null    object
#  6   size        244 non-null    int64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 13.5+ KB

# %%
df.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
df.values
# Out:
# array([[16.99, 1.01, 'Female', ..., 'Sun', 'Dinner', 2],
#        [10.34, 1.66, 'Male', ..., 'Sun', 'Dinner', 3],
#        [21.01, 3.5, 'Male', ..., 'Sun', 'Dinner', 3],
#        ...,
#        [22.67, 2.0, 'Male', ..., 'Sat', 'Dinner', 2],
#        [17.82, 1.75, 'Male', ..., 'Sat', 'Dinner', 2],
#        [18.78, 3.0, 'Female', ..., 'Thur', 'Dinner', 2]], dtype=object)

# %%
print("All Males who tips")
male= df.loc[df["sex"] == "Male"]
male
# Out:
# All Males who tips
#      total_bill   tip   sex smoker  day    time  size
# 1         10.34  1.66  Male     No  Sun  Dinner     3
# 2         21.01  3.50  Male     No  Sun  Dinner     3
# 3         23.68  3.31  Male     No  Sun  Dinner     2
# 5         25.29  4.71  Male     No  Sun  Dinner     4
# 6          8.77  2.00  Male     No  Sun  Dinner     2
# ..          ...   ...   ...    ...  ...     ...   ...
# 236       12.60  1.00  Male    Yes  Sat  Dinner     2
# 237       32.83  1.17  Male    Yes  Sat  Dinner     2
# 239       29.03  5.92  Male     No  Sat  Dinner     3
# 241       22.67  2.00  Male    Yes  Sat  Dinner     2
# 242       17.82  1.75  Male     No  Sat  Dinner     2
#
# [157 rows x 7 columns]

# %%
print("properties of all the males who tips")
male.describe().T.style.set_properties(**{"background-color": "lightblue","color":"black","border": "1.5px  solid black"})
# Out:
# properties of all the males who tips
# <style type="text/css">
# #T_c7f6a_row0_col0, #T_c7f6a_row0_col1, #T_c7f6a_row0_col2, #T_c7f6a_row0_col3, #T_c7f6a_row0_col4, #T_c7f6a_row0_col5, #T_c7f6a_row0_col6, #T_c7f6a_row0_col7, #T_c7f6a_row1_col0, #T_c7f6a_row1_col1, #T_c7f6a_row1_col2, #T_c7f6a_row1_col3, #T_c7f6a_row1_col4, #T_c7f6a_row1_col5, #T_c7f6a_row1_col6, #T_c7f6a_row1_col7, #T_c7f6a_row2_col0, #T_c7f6a_row2_col1, #T_c7f6a_row2_col2, #T_c7f6a_row2_col3, #T_c7f6a_row2_col4, #T_c7f6a_row2_col5, #T_c7f6a_row2_col6, #T_c7f6a_row2_col7 {
#   background-color: lightblue;
#   color: black;
#   border: 1.5px  solid black;
# }
# </style>
# <table id="T_c7f6a" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c7f6a_level0_col0" class="col_heading level0 col0" >count</th>
#       <th id="T_c7f6a_level0_col1" class="col_heading level0 col1" >mean</th>
#       <th id="T_c7f6a_level0_col2" class="col_heading level0 col2" >std</th>
# ...

# %%
print("Females who tips")
female= df.loc[df["sex"] == "Female"]
female
# Out:
# Females who tips
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# 11        35.26  5.00  Female     No   Sun  Dinner     4
# 14        14.83  3.02  Female     No   Sun  Dinner     2
# 16        10.33  1.67  Female     No   Sun  Dinner     3
# ..          ...   ...     ...    ...   ...     ...   ...
# 226       10.09  2.00  Female    Yes   Fri   Lunch     2
# 229       22.12  2.88  Female    Yes   Sat  Dinner     2
# 238       35.83  4.67  Female     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [87 rows x 7 columns]

# %%
print("properties of all females who tips")
female.describe().T.style.set_properties(**{"background-color": "lightblue","color":"black","border": "1.5px  solid black"})
# Out:
# properties of all females who tips
# <style type="text/css">
# #T_fe484_row0_col0, #T_fe484_row0_col1, #T_fe484_row0_col2, #T_fe484_row0_col3, #T_fe484_row0_col4, #T_fe484_row0_col5, #T_fe484_row0_col6, #T_fe484_row0_col7, #T_fe484_row1_col0, #T_fe484_row1_col1, #T_fe484_row1_col2, #T_fe484_row1_col3, #T_fe484_row1_col4, #T_fe484_row1_col5, #T_fe484_row1_col6, #T_fe484_row1_col7, #T_fe484_row2_col0, #T_fe484_row2_col1, #T_fe484_row2_col2, #T_fe484_row2_col3, #T_fe484_row2_col4, #T_fe484_row2_col5, #T_fe484_row2_col6, #T_fe484_row2_col7 {
#   background-color: lightblue;
#   color: black;
#   border: 1.5px  solid black;
# }
# </style>
# <table id="T_fe484" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fe484_level0_col0" class="col_heading level0 col0" >count</th>
#       <th id="T_fe484_level0_col1" class="col_heading level0 col1" >mean</th>
#       <th id="T_fe484_level0_col2" class="col_heading level0 col2" >std</th>
# ...

# %%
print("A graph analysing males and females who tips with respect to total bill")
sns.scatterplot(x='total_bill',y='tip',data=df,hue='sex')
# Out:
# A graph analysing males and females who tips with respect to total bill
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
print("Analysing the time with maximum number of males and females")
sns.countplot(x='time',data=df)
# Out:
# Analysing the time with maximum number of males and females
# <Axes: xlabel='time', ylabel='count'>

# %%
print("Analysing the time most visited by both males and females")
sns.jointplot(x='sex',y='time',data=df)
# Out:
# Analysing the time most visited by both males and females

# %%
print("Analysing the day visited by most number of customes")
mostcust= sns.countplot(x='day', data=df)
# Out:
# Analysing the day visited by most number of customes

# %%
print("Analysing the number of males and females who visited most on saturdays")
sns.jointplot(x='day',y='sex',data=df)
# Out:
# Analysing the number of males and females who visited most on saturdays

# %%
sns.jointplot(x='total_bill',y='tip',data=df,kind='reg')
